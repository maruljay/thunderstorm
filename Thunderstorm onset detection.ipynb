# %%
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, "C:\\Users\\maruljay\\Anaconda3\\lib\\site-packages\\BMC\\functions")

# %%
from detect_onset import detect_onset

# %%
my_data = genfromtxt('C:/Users/maruljay/Desktop/test.csv', delimiter=',')

# %%
detect_onset(my_data, threshold=10, n_above=10, n_below=0, show=True)
# Out:
# array([[382, 403],
#        [419, 433],
#        [469, 500],
#        [502, 515],
#        [637, 648]], dtype=int64)

# %%
detect_onset(my_data, threshold=11, n_above=10, n_below=2, show=True)
# Out:
# array([[382, 402],
#        [482, 497]], dtype=int64)
